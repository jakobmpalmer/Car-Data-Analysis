# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
cars= pd.read_csv('/Users/jakepalmer/Desktop/DATASETS/Car_data.csv')

# %% [markdown]
# #1. Less than $45,000 and Convertable

# %%
less_than_price = cars['MSRP'] < 45000
convert = cars['Vehicle Style'] == "Convertible"

cars.loc[(less_than_price & convert)]
# Out:
#       Make     Model  Year             Engine Fuel Type  Engine HP  \
# 1      BMW  1 Series  2011  premium unleaded (required)      300.0
# 4      BMW  1 Series  2011  premium unleaded (required)      230.0
# 6      BMW  1 Series  2012  premium unleaded (required)      300.0
# 8      BMW  1 Series  2012  premium unleaded (required)      230.0
# 9      BMW  1 Series  2013  premium unleaded (required)      230.0
# ...    ...       ...   ...                          ...        ...
# 11883  BMW        Z3  2000             regular unleaded      170.0
# 11884  BMW        Z3  2001  premium unleaded (required)      225.0
# 11885  BMW        Z3  2001  premium unleaded (required)      184.0
# 11887  BMW        Z3  2002  premium unleaded (required)      225.0
# 11888  BMW        Z3  2002  premium unleaded (required)      184.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 1                   6.0            MANUAL  rear wheel drive              2.0
# ...

# %%
#2. 4 door Toyota w/ more than 25 mpg_H made after 2016

# %%
four_door = cars['Number of Doors'] == 4.0
correct_mpg = cars['highway MPG'] > 25
year = cars['Year'] > 2016
toyota = cars['Make'] == 'Toyota'

cars.loc[(correct_mpg & four_door & year & toyota)]
# Out:
#          Make          Model  Year  Engine Fuel Type  Engine HP  \
# 1592   Toyota  Avalon Hybrid  2017  regular unleaded      200.0
# 1593   Toyota  Avalon Hybrid  2017  regular unleaded      200.0
# 1594   Toyota  Avalon Hybrid  2017  regular unleaded      200.0
# 1605   Toyota         Avalon  2017  regular unleaded      268.0
# 1606   Toyota         Avalon  2017  regular unleaded      268.0
# ...       ...            ...   ...               ...        ...
# 11810  Toyota       Yaris iA  2017  regular unleaded      106.0
# 11828  Toyota          Yaris  2017  regular unleaded      106.0
# 11829  Toyota          Yaris  2017  regular unleaded      106.0
# 11830  Toyota          Yaris  2017  regular unleaded      106.0
# 11831  Toyota          Yaris  2017  regular unleaded      106.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 1592                4.0         AUTOMATIC  front wheel drive              4.0
# ...

# %%
# 3. 6 cylinder Ford w/ less than 12 mpg_c

# %%
six_cylinder = cars['Engine Cylinders'] == 6.0
ford = cars['Make'] == 'Ford'
our_mpgC = cars['city mpg'] < 12

cars.loc[(ford & our_mpgC & six_cylinder)]
# Out:
#        Make         Model  Year             Engine Fuel Type  Engine HP  \
# 294    Ford           360  2002  premium unleaded (required)      400.0
# 295    Ford           360  2002  premium unleaded (required)      400.0
# 296    Ford           360  2002  premium unleaded (required)      400.0
# 297    Ford           360  2002  premium unleaded (required)      400.0
# 298    Ford           360  2003  premium unleaded (required)      400.0
# ...     ...           ...   ...                          ...        ...
# 11104  Ford   V12 Vantage  2012  premium unleaded (required)      510.0
# 11362  Ford   Veyron 16.4  2008  premium unleaded (required)     1001.0
# 11363  Ford   Veyron 16.4  2008  premium unleaded (required)     1001.0
# 11364  Ford   Veyron 16.4  2009  premium unleaded (required)     1001.0
# 11832  Ford  Yukon Denali  2000             regular unleaded      255.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %%
# 4. Highest mpg_H, under $30,000 w/ manuel transmission
price = cars['MSRP'] < 30000
transmission = cars['Transmission Type'] == 'MANUAL'

cars[(transmission & price)].sort_values(by=['highway MPG'], ascending=False)
# Out:
#       Make       Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 9872  Ford    Spark EV  2016          electric      140.0               6.0
# 9867  Ford    Spark EV  2014          electric      140.0               6.0
# 9871  Ford    Spark EV  2016          electric      140.0               6.0
# 9870  Ford    Spark EV  2015          electric      140.0               6.0
# 9869  Ford    Spark EV  2015          electric      140.0               6.0
# ...    ...         ...   ...               ...        ...               ...
# 8082  Ford     RAM 250  1991  regular unleaded      170.0               6.0
# 8224  Ford  Ramcharger  1991  regular unleaded      170.0               6.0
# 8221  Ford  Ramcharger  1991  regular unleaded      170.0               6.0
# 8225  Ford  Ramcharger  1991  regular unleaded      170.0               6.0
# 8223  Ford  Ramcharger  1991  regular unleaded      170.0               6.0
#
# ...

# %%
# 5. Highest HP in 2015 by Ford
year = cars['Year'] == 2015
ford = cars['Make'] == 'Ford'
horsepwr = 'Engine HP'

# %%
cars.loc[(ford & year)].sort_values(by=['Engine HP'])
# Out:
#       Make    Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 6834  Ford   Mirage  2015  regular unleaded       74.0               6.0
# 6832  Ford   Mirage  2015  regular unleaded       74.0               6.0
# 6836  Ford   Mirage  2015  regular unleaded       74.0               6.0
# 6835  Ford   Mirage  2015  regular unleaded       74.0               6.0
# 6833  Ford   Mirage  2015  regular unleaded       74.0               6.0
# ...    ...      ...   ...               ...        ...               ...
# 6927  Ford  Model S  2015          electric        NaN               6.0
# 6928  Ford  Model S  2015          electric        NaN               6.0
# 6929  Ford  Model S  2015          electric        NaN               6.0
# 9850  Ford  Soul EV  2015          electric        NaN               6.0
# 9851  Ford  Soul EV  2015          electric        NaN               6.0
#
#      Transmission Type      Driven_Wheels  Number of Doors  \
# ...

# %%
print(cars.head())
# Out:
#    Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  Ford  1 Series M  2011  premium unleaded (required)      335.0
# 1  Ford    1 Series  2011  premium unleaded (required)      300.0
# 2  Ford    1 Series  2011  premium unleaded (required)      300.0
# 3  Ford    1 Series  2011  premium unleaded (required)      230.0
# 4  Ford    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %% [markdown]
# #OTHER GROUP: QUESTIONS#
# 1. Whats the best car with the highest Highway MPG

# %% [markdown]
# 2. Car with the highest city mpg under $20k
